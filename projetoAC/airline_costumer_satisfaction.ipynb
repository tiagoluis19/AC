# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv("train.csv")
data_test = pd.read_csv("test.csv")
data.shape
#data.info()
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25976 entries, 0 to 25975
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         25976 non-null  int64
#  1   id                                 25976 non-null  int64
#  2   Gender                             25976 non-null  object
#  3   Customer Type                      25976 non-null  object
#  4   Age                                25976 non-null  int64
#  5   Type of Travel                     25976 non-null  object
#  6   Class                              25976 non-null  object
#  7   Flight Distance                    25976 non-null  int64
#  8   Inflight wifi service              25976 non-null  int64
#  9   Departure/Arrival time convenient  25976 non-null  int64
#  10  Ease of Online booking             25976 non-null  int64
#  11  Gate location                      25976 non-null  int64
#  12  Food and drink                     25976 non-null  int64
#  13  Online boarding                    25976 non-null  int64
#  14  Seat comfort                       25976 non-null  int64
#  15  Inflight entertainment             25976 non-null  int64
#  16  On-board service                   25976 non-null  int64
#  17  Leg room service                   25976 non-null  int64
#  18  Baggage handling                   25976 non-null  int64
#  19  Checkin service                    25976 non-null  int64
#  20  Inflight service                   25976 non-null  int64
#  21  Cleanliness                        25976 non-null  int64
#  22  Departure Delay in Minutes         25976 non-null  int64
#  23  Arrival Delay in Minutes           25893 non-null  float64
#  24  satisfaction                       25976 non-null  object
# dtypes: float64(1), int64(19), object(5)
# memory usage: 5.0+ MB

# %%
data.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# 2                                  2  ...                       5
# 3                                  5  ...                       2
# 4                                  3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 25 columns]

# %%
data.tail()
# Out:
#         Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 103899      103899  94171  Female  disloyal Customer   23  Business travel
# 103900      103900  73097    Male     Loyal Customer   49  Business travel
# 103901      103901  68825    Male  disloyal Customer   30  Business travel
# 103902      103902  54173  Female  disloyal Customer   22  Business travel
# 103903      103903  62567    Male     Loyal Customer   27  Business travel
#
#            Class  Flight Distance  Inflight wifi service  \
# 103899       Eco              192                      2
# 103900  Business             2347                      4
# 103901  Business             1995                      1
# 103902       Eco             1000                      1
# 103903  Business             1723                      1
#
#         Departure/Arrival time convenient  ...  Inflight entertainment  \
# 103899                                  1  ...                       2
# 103900                                  4  ...                       5
# 103901                                  1  ...                       4
# 103902                                  1  ...                       1
# 103903                                  3  ...                       1
#
#         On-board service  Leg room service  Baggage handling  Checkin service  \
# 103899                 3                 1                 4                2
# 103900                 5                 5                 5                5
# 103901                 3                 2                 4                5
# 103902                 4                 5                 1                5
# 103903                 1                 1                 4                4
#
#         Inflight service  Cleanliness  Departure Delay in Minutes  \
# 103899                 3            2                           3
# 103900                 5            4                           0
# 103901                 5            4                           7
# 103902                 4            1                           0
# 103903                 3            1                           0
#
#         Arrival Delay in Minutes             satisfaction
# 103899                       0.0  neutral or dissatisfied
# 103900                       0.0                satisfied
# 103901                      14.0  neutral or dissatisfied
# 103902                       0.0  neutral or dissatisfied
# 103903                       0.0  neutral or dissatisfied
#
# [5 rows x 25 columns]

# %%
data.info()
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
#  11  Gate location                      103904 non-null  int64
#  12  Food and drink                     103904 non-null  int64
#  13  Online boarding                    103904 non-null  int64
#  14  Seat comfort                       103904 non-null  int64
#  15  Inflight entertainment             103904 non-null  int64
#  16  On-board service                   103904 non-null  int64
#  17  Leg room service                   103904 non-null  int64
#  18  Baggage handling                   103904 non-null  int64
#  19  Checkin service                    103904 non-null  int64
#  20  Inflight service                   103904 non-null  int64
#  21  Cleanliness                        103904 non-null  int64
#  22  Departure Delay in Minutes         103904 non-null  int64
#  23  Arrival Delay in Minutes           103594 non-null  float64
#  24  satisfaction                       103904 non-null  object
# dtypes: float64(1), int64(19), object(5)
# memory usage: 19.8+ MB

# %% [markdown]
# limeza das duas primeiras colunas que têm features inuteis

# %%
data = data.drop(data.iloc[:,[0,1]],axis=1)
data_test = data_test.drop(data_test.iloc[:,[0,1]],axis=1)

# %%
le=LabelEncoder()

data['Gender']=le.fit_transform(data['Gender'])
data['Customer Type']=le.fit_transform(data['Customer Type'])
data['Class']=le.fit_transform(data['Class'])
data['Type of Travel']=le.fit_transform(data['Type of Travel'])
data['satisfaction']=le.fit_transform(data['satisfaction'])
data.info()

data_test['Gender']=le.fit_transform(data_test['Gender'])
data_test['Customer Type']=le.fit_transform(data_test['Customer Type'])
data_test['Class']=le.fit_transform(data_test['Class'])
data_test['Type of Travel']=le.fit_transform(data_test['Type of Travel'])
data_test['satisfaction']=le.fit_transform(data_test['satisfaction'])
#ata_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103904 non-null  int64
#  1   Customer Type                      103904 non-null  int64
#  2   Age                                103904 non-null  int64
#  3   Type of Travel                     103904 non-null  int64
#  4   Class                              103904 non-null  int64
#  5   Flight Distance                    103904 non-null  int64
#  6   Inflight wifi service              103904 non-null  int64
#  7   Departure/Arrival time convenient  103904 non-null  int64
#  8   Ease of Online booking             103904 non-null  int64
#  9   Gate location                      103904 non-null  int64
#  10  Food and drink                     103904 non-null  int64
#  11  Online boarding                    103904 non-null  int64
#  12  Seat comfort                       103904 non-null  int64
#  13  Inflight entertainment             103904 non-null  int64
#  14  On-board service                   103904 non-null  int64
#  15  Leg room service                   103904 non-null  int64
#  16  Baggage handling                   103904 non-null  int64
#  17  Checkin service                    103904 non-null  int64
#  18  Inflight service                   103904 non-null  int64
#  19  Cleanliness                        103904 non-null  int64
#  20  Departure Delay in Minutes         103904 non-null  int64
#  21  Arrival Delay in Minutes           103594 non-null  float64
#  22  satisfaction                       103904 non-null  int64
# dtypes: float64(1), int64(22)
# memory usage: 18.2 MB

# %%
data.describe()
# Out:
#               Gender  Customer Type            Age  Type of Travel  \
# count  103904.000000  103904.000000  103904.000000   103904.000000
# mean        0.492541       0.182678      39.379706        0.310373
# std         0.499947       0.386404      15.114964        0.462649
# min         0.000000       0.000000       7.000000        0.000000
# 25%         0.000000       0.000000      27.000000        0.000000
# 50%         0.000000       0.000000      40.000000        0.000000
# 75%         1.000000       0.000000      51.000000        1.000000
# max         1.000000       1.000000      85.000000        1.000000
#
#                Class  Flight Distance  Inflight wifi service  \
# count  103904.000000    103904.000000          103904.000000
# mean        0.594135      1189.448375               2.729683
# std         0.620799       997.147281               1.327829
# min         0.000000        31.000000               0.000000
# 25%         0.000000       414.000000               2.000000
# 50%         1.000000       843.000000               3.000000
# 75%         1.000000      1743.000000               4.000000
# max         2.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      103904.000000           103904.000000
# mean                            3.060296                2.756901
# std                             1.525075                1.398929
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# 50%                             3.000000                3.000000
# 75%                             4.000000                4.000000
# max                             5.000000                5.000000
#
#        Gate location  ...  Inflight entertainment  On-board service  \
# count  103904.000000  ...           103904.000000     103904.000000
# mean        2.976883  ...                3.358158          3.382363
# std         1.277621  ...                1.332991          1.288354
# min         0.000000  ...                0.000000          0.000000
# 25%         2.000000  ...                2.000000          2.000000
# 50%         3.000000  ...                4.000000          4.000000
# 75%         4.000000  ...                4.000000          4.000000
# max         5.000000  ...                5.000000          5.000000
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# count     103904.000000     103904.000000    103904.000000     103904.000000
# mean           3.351055          3.631833         3.304290          3.640428
# std            1.315605          1.180903         1.265396          1.175663
# min            0.000000          1.000000         0.000000          0.000000
# 25%            2.000000          3.000000         3.000000          3.000000
# 50%            4.000000          4.000000         3.000000          4.000000
# 75%            4.000000          5.000000         4.000000          5.000000
# max            5.000000          5.000000         5.000000          5.000000
#
#          Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# count  103904.000000               103904.000000             103594.000000
# mean        3.286351                   14.815618                 15.178678
# std         1.312273                   38.230901                 38.698682
# min         0.000000                    0.000000                  0.000000
# 25%         2.000000                    0.000000                  0.000000
# 50%         3.000000                    0.000000                  0.000000
# 75%         4.000000                   12.000000                 13.000000
# max         5.000000                 1592.000000               1584.000000
#
#         satisfaction
# count  103904.000000
# mean        0.433333
# std         0.495538
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
#
# [8 rows x 23 columns]

# %%
data.describe(include = ['int64'])
# Out:
#               Gender  Customer Type            Age  Type of Travel  \
# count  103904.000000  103904.000000  103904.000000   103904.000000
# mean        0.492541       0.182678      39.379706        0.310373
# std         0.499947       0.386404      15.114964        0.462649
# min         0.000000       0.000000       7.000000        0.000000
# 25%         0.000000       0.000000      27.000000        0.000000
# 50%         0.000000       0.000000      40.000000        0.000000
# 75%         1.000000       0.000000      51.000000        1.000000
# max         1.000000       1.000000      85.000000        1.000000
#
#                Class  Flight Distance  Inflight wifi service  \
# count  103904.000000    103904.000000          103904.000000
# mean        0.594135      1189.448375               2.729683
# std         0.620799       997.147281               1.327829
# min         0.000000        31.000000               0.000000
# 25%         0.000000       414.000000               2.000000
# 50%         1.000000       843.000000               3.000000
# 75%         1.000000      1743.000000               4.000000
# max         2.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      103904.000000           103904.000000
# mean                            3.060296                2.756901
# std                             1.525075                1.398929
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# 50%                             3.000000                3.000000
# 75%                             4.000000                4.000000
# max                             5.000000                5.000000
#
#        Gate location  ...   Seat comfort  Inflight entertainment  \
# count  103904.000000  ...  103904.000000           103904.000000
# mean        2.976883  ...       3.439396                3.358158
# std         1.277621  ...       1.319088                1.332991
# min         0.000000  ...       0.000000                0.000000
# 25%         2.000000  ...       2.000000                2.000000
# 50%         3.000000  ...       4.000000                4.000000
# 75%         4.000000  ...       5.000000                4.000000
# max         5.000000  ...       5.000000                5.000000
#
#        On-board service  Leg room service  Baggage handling  Checkin service  \
# count     103904.000000     103904.000000     103904.000000    103904.000000
# mean           3.382363          3.351055          3.631833         3.304290
# std            1.288354          1.315605          1.180903         1.265396
# min            0.000000          0.000000          1.000000         0.000000
# 25%            2.000000          2.000000          3.000000         3.000000
# 50%            4.000000          4.000000          4.000000         3.000000
# 75%            4.000000          4.000000          5.000000         4.000000
# max            5.000000          5.000000          5.000000         5.000000
#
#        Inflight service    Cleanliness  Departure Delay in Minutes  \
# count     103904.000000  103904.000000               103904.000000
# mean           3.640428       3.286351                   14.815618
# std            1.175663       1.312273                   38.230901
# min            0.000000       0.000000                    0.000000
# 25%            3.000000       2.000000                    0.000000
# 50%            4.000000       3.000000                    0.000000
# 75%            5.000000       4.000000                   12.000000
# max            5.000000       5.000000                 1592.000000
#
#         satisfaction
# count  103904.000000
# mean        0.433333
# std         0.495538
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
#
# [8 rows x 22 columns]

# %%
fig, axs = plt.subplots(5,5,figsize=(32,32))
axs[0,0].pie(data.Gender.value_counts(),labels = ["Male", "Female"], colors = sns.color_palette("Paired"), autopct = '%1.1f%%')
axs[0,0].set_title("Gender Distribution") 
axs[0,1].pie(data["Customer Type"].value_counts(),labels = ["Loyal custumer", "Disloyal Custumer"], colors = sns.color_palette("Paired"), autopct = '%1.1f%%')
axs[0,1].set_title("Customer Type Distribution")
axs[0,2].hist(data["Age"])
axs[0,2].set_title("Age Distribution")
axs[0,2].set_xlabel("Age of Passengers")
axs[0,2].set_ylabel("Number of Passengers")
axs[0,3].pie(data["Type of Travel"].value_counts(),labels = ["Business", "Pleasure"], colors = sns.color_palette("Paired"), autopct = '%1.1f%%')
axs[0,3].set_title("Type of Travel Distribution")
axs[0,4].pie(data.Class.value_counts(),labels = ["economy","business","eco pro"],colors = sns.color_palette("Paired"),autopct = '%1.1f%%')
axs[0,4].set_title("Passenger Class Distribution")

axs[1,0].hist(data["Flight Distance"],)
axs[1,0].set_title("Flight Distance Histogram")
axs[1,0].set_xlabel("Flight Distance")
axs[1,0].set_ylabel("Number of Passengers")

axs[1,1].pie(data["Inflight wifi service"].value_counts(), labels = ["0","1","2","3","4","5"], colors = sns.color_palette("Paired"), autopct = '%1.1f%%')
axs[1,1].set_title("Inflight wifi service")
axs[1,2].pie(data["Departure/Arrival time convenient"].value_counts(), labels = ["0","1","2","3","4","5"], colors = sns.color_palette("Paired"), autopct = '%1.1f%%')
axs[1,2].set_title("Departure/Arrival time convenient")
axs[1,3].pie(data["Ease of Online booking"].value_counts(), labels = ["0","1","2","3","4","5"], colors = sns.color_palette("Paired"), autopct = '%1.1f%%')
axs[1,3].set_title("Ease of Online booking")
axs[1,4].pie(data["Gate location"].value_counts(), labels = ["0","1","2","3","4","5"], colors = sns.color_palette("Paired"), autopct = '%1.1f%%')
axs[1,4].set_title("Gate location")

axs[2,0].pie(data["Food and drink"].value_counts(), labels = ["0","1","2","3","4","5"], colors = sns.color_palette("Paired"), autopct = '%1.1f%%')
axs[2,0].set_title("Food and drink Quality")
axs[2,1].pie(data["Online boarding"].value_counts(), labels = ["0","1","2","3","4","5"], colors = sns.color_palette("Paired"), autopct = '%1.1f%%')
axs[2,1].set_title("Online boarding")
axs[2,2].pie(data["Seat comfort"].value_counts(), labels = ["0","1","2","3","4","5"], colors = sns.color_palette("Paired"), autopct = '%1.1f%%')
axs[2,2].set_title("Seat comfort")
axs[2,3].pie(data["Inflight entertainment"].value_counts(), labels = ["0","1","2","3","4","5"], colors = sns.color_palette("Paired"), autopct = '%1.1f%%')
axs[2,3].set_title("Inflight entertainment")
axs[2,4].pie(data["On-board service"].value_counts(), labels = ["0","1","2","3","4","5"], colors = sns.color_palette("Paired"), autopct = '%1.1f%%')
axs[2,4].set_title("On-board service Quality")

axs[3,0].pie(data["Leg room service"].value_counts(), labels = ["0","1","2","3","4","5"], colors = sns.color_palette("Paired"), autopct = '%1.1f%%')
axs[3,0].set_title("Leg room service")
axs[3,1].pie(data["Baggage handling"].value_counts(), labels = ["1","2","3","4","5"], colors = sns.color_palette("Paired"), autopct = '%1.1f%%')
axs[3,1].set_title("Baggage handling")
axs[3,2].pie(data["Checkin service"].value_counts(), labels = ["0","1","2","3","4","5"], colors = sns.color_palette("Paired"), autopct = '%1.1f%%')
axs[3,2].set_title("Checkin service")
axs[3,3].pie(data["Inflight service"].value_counts(), labels = ["0","1","2","3","4","5"], colors = sns.color_palette("Paired"), autopct = '%1.1f%%')
axs[3,3].set_title("Inflight service")
axs[3,4].pie(data["Cleanliness"].value_counts(), labels = ["0","1","2","3","4","5"], colors = sns.color_palette("Paired"), autopct = '%1.1f%%')
axs[3,4].set_title("Cleanliness")

axs[4,0].hist(data["Departure Delay in Minutes"])
axs[4,0].set_title("Departure Delay in Minutes")
axs[4,0].set_xlabel("Departure Delay in Minutes")
axs[4,0].set_ylabel("Number of Passengers")


axs[4,1].pie(data.satisfaction.value_counts(), labels = ["Neutral or dissatisfied", "Satisfied"], colors = sns.color_palette("Paired"), autopct = '%1.1f%%') 
axs[4,1].set_title("Satisfaction of Passengers Distribution")
axs[4,2].set_visible(False)
axs[4,3].set_visible(False)
axs[4,4].set_visible(False)

plt.tight_layout()

# %%
plt.figure(figsize=(6, 6))  # Adjust the figure size to make it smaller
plt.pie(data.satisfaction.value_counts(), labels=["Neutral or dissatisfied", "Satisfied"], colors=sns.color_palette("Paired"), autopct='%1.1f%%')
#plt.legend(title="Satisfaction of Passengers Distribution", bbox_to_anchor=(1, 0.5), loc="center left")  # Position the title like the labels
plt.show()

# %%
coluna = 'Age'  # 🔄 Substitua pelo nome real da coluna

# Obter os dois valores únicos da coluna
valores = data[coluna].dropna().unique()[:2]  # Pegamos apenas 2 valores distintos

# Criar conjuntos com os índices das ocorrências
set1 = set(data.index[data[coluna] == valores[0]])
set2 = set(data.index[data[coluna] == valores[1]])

# Criar o diagrama de Venn
plt.figure(figsize=(6,6))
venn2([set1, set2], set_labels=[str(valores[0]), str(valores[1])])
plt.title(f"Diagrama de Venn - {coluna}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 12
#      10 # Criar o diagrama de Venn
#      11 plt.figure(figsize=(6,6))
# ---> 12 venn2([set1, set2], set_labels=[str(valores[0]), str(valores[1])])
#      13 plt.title(f"Diagrama de Venn - {coluna}")
#      14 plt.show()
#
# NameError: name 'venn2' is not defined

# %%
numerical_cols = ['Gender','Age','Flight Distance','Departure Delay in Minutes']

# Criar múltiplos boxplots
plt.figure(figsize=(15, 6))
data[numerical_cols].boxplot(rot=45)  # Rotacionar rótulos para melhor visualização
plt.title("Boxplots das Variáveis Numéricas")
plt.show()

# %%
corr_mat = data.corr()
sns.set_theme(rc={'figure.figsize':(30,30)})
sns.heatmap(corr_mat,annot=True,cmap='Spectral_r',xticklabels=True,yticklabels=True,fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# By analyzing the matrix we cas see that there is high correlation (97%) between the features 'Departure delay' and 'Arrival delay' so we can drop one of them

# %%
data = data.drop(["Arrival Delay in Minutes"],axis=1)
data_test = data_test.drop(["Arrival Delay in Minutes"],axis=1)

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN 
from sklearn.metrics import accuracy_score ,confusion_matrix, f1_score


#KNN sem normalizaçao runtime 28 seg ??????? expectavel para 103904 linhas por 21 colunas

knn= KNN(9)
X_train = data.drop(['satisfaction'],axis=1)
y_train=data['satisfaction']
#y_train=

print("pre fit")
knn.fit(X_train,y_train)
print("pos fit")
X_test = data_test.drop(['satisfaction'],axis=1)
y_test = data_test['satisfaction']

print(X_train.shape)
print(X_test.shape)
print("pre predict")
y_pred=knn.predict(X_test)
print("pos predict")


print(accuracy_score(y_true=y_test,y_pred=y_pred))
print(confusion_matrix(y_true=y_test,y_pred=y_pred))
print(f1_score(y_true=y_test,y_pred=y_pred))
# Out:
# pre fit
# pos fit
# (103904, 21)
# (25976, 21)
# pre predict
# pos predict
# 0.7622035725284878
# [[12130  2443]
#  [ 3734  7669]]
# 0.7128979781547757

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN 
from sklearn.metrics import accuracy_score ,confusion_matrix

X_train = data.drop(['satisfaction'], axis=1)
y_train = data['satisfaction']
X_test = data_test.drop(['satisfaction'], axis=1)
y_test = data_test['satisfaction']

accuracies = []

# Loop through K values from 1 to 20
for i in range(1, 21):
    knn = KNN(n_neighbors=i)  # Create KNN with i neighbors
    knn.fit(X_train, y_train)  # Train the model
    y_pred = knn.predict(X_test)  # Predict
    acc = accuracy_score(y_true=y_test, y_pred=y_pred)  # Compute accuracy
    accuracies.append(acc)  # Store accuracy

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(range(1, 21), accuracies, marker='o', linestyle='-')
plt.xlabel("Number of Neighbors (K)")
plt.ylabel("Accuracy Score")
plt.title("KNN Accuracy vs. Number of Neighbors")
plt.xticks(range(1, 21))
plt.grid(True)

plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN 
from sklearn.metrics import accuracy_score ,confusion_matrix

X_train = data.drop(['satisfaction'], axis=1)
y_train = data['satisfaction']
X_test = data_test.drop(['satisfaction'], axis=1)
y_test = data_test['satisfaction']

accuracies = []
f1_scores = []

# Loop through K values from 1 to 30
for i in range(1, 21):
    knn = KNeighborsClassifier(n_neighbors=i)  # Create KNN with i neighbors
    knn.fit(X_train, y_train)  # Train the model
    y_pred = knn.predict(X_test)  # Predict
    acc = accuracy_score(y_true=y_test, y_pred=y_pred)  # Compute accuracy
    f1 = f1_score(y_true=y_test, y_pred=y_pred, average='weighted')  # Compute F1 score
    
    accuracies.append(acc)  # Store accuracy
    f1_scores.append(f1)  # Store F1 score

# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(range(1, 21), accuracies, marker='o', linestyle='-', label='Accuracy')
plt.plot(range(1, 21), f1_scores, marker='s', linestyle='', label='F1 Score', color='red')

# Annotate accuracy and F1 score values at selected intervals
for i in range(1, 21, 3):  # Annotate every 3rd point for readability
    plt.text(i, accuracies[i-1], f'{accuracies[i-1]:.2f}', ha='center', va='bottom', fontsize=10)
    plt.text(i, f1_scores[i-1], f'{f1_scores[i-1]:.2f}', ha='center', va='top', fontsize=10, color='red')

plt.xlabel("Number of Neighbors (K)")
plt.ylabel("Score")
plt.title("KNN Accuracy & F1 Score vs. Number of Neighbors (Standardized Data)")
plt.xticks(range(1, 21))
plt.grid(True)
plt.legend()
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN 
from sklearn.metrics import accuracy_score ,confusion_matrix ,f1_score
from sklearn.preprocessing import StandardScaler

#KNN com normalizaçao runtime de 1-2 segundos???????????????????????????? n faz sentido!!!!!!!!!!!

knn= KNN(7)
X_train = data.drop(['satisfaction'],axis=1)
y_train=data['satisfaction']
#y_train=
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)


knn.fit(X_train,y_train)


X_test = data_test.drop(['satisfaction'],axis=1)
X_test = scaler.transform(X_test)
y_test = data_test['satisfaction']

y_pred=knn.predict(X_test)


print(accuracy_score(y_true=y_test,y_pred=y_pred))
print(confusion_matrix(y_true=y_test,y_pred=y_pred))
print(f1_score(y_true=y_test,y_pred=y_pred))
# Out:
# 0.9310517400677548
# [[14069   504]
#  [ 1287 10116]]
# 0.9186759297098488

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Assuming 'data' and 'data_test' are already defined

X_train = data.drop(['satisfaction'], axis=1)
y_train = data['satisfaction']
X_test = data_test.drop(['satisfaction'], axis=1)
y_test = data_test['satisfaction']

# Standardizing the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

accuracies = []

# Loop through K values from 1 to 20
for i in range(1, 31):
    knn = KNeighborsClassifier(n_neighbors=i)  # Create KNN with i neighbors
    knn.fit(X_train, y_train)  # Train the model
    y_pred = knn.predict(X_test)  # Predict
    acc = accuracy_score(y_true=y_test, y_pred=y_pred)  # Compute accuracy
    accuracies.append(acc)  # Store accuracy

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(range(1, 31), accuracies, marker='o', linestyle='-')
plt.xlabel("Number of Neighbors (K)")
plt.ylabel("Accuracy Score")
plt.title("KNN Accuracy vs. Number of Neighbors (Standardized Data)")
plt.xticks(range(1, 31))
plt.grid(True)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.preprocessing import StandardScaler

# Assuming 'data' and 'data_test' are already defined
X_train = data.drop(['satisfaction'], axis=1)
y_train = data['satisfaction']
X_test = data_test.drop(['satisfaction'], axis=1)
y_test = data_test['satisfaction']

# Standardizing the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

accuracies = []
f1_scores = []

# Loop through K values from 1 to 30
for i in range(1, 31):
    knn = KNeighborsClassifier(n_neighbors=i)  # Create KNN with i neighbors
    knn.fit(X_train, y_train)  # Train the model
    y_pred = knn.predict(X_test)  # Predict
    acc = accuracy_score(y_true=y_test, y_pred=y_pred)  # Compute accuracy
    f1 = f1_score(y_true=y_test, y_pred=y_pred, average='weighted')  # Compute F1 score
    
    accuracies.append(acc)  # Store accuracy
    f1_scores.append(f1)  # Store F1 score

# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(range(1, 31), accuracies, marker='o', linestyle='-', label='Accuracy')
plt.plot(range(1, 31), f1_scores, marker='s', linestyle='', label='F1 Score', color='red')

# Annotate accuracy and F1 score values at selected intervals
for i in range(1, 31, 3):  # Annotate every 3rd point for readability
    plt.text(i, accuracies[i-1], f'{accuracies[i-1]:.2f}', ha='center', va='bottom', fontsize=10)
    plt.text(i, f1_scores[i-1], f'{f1_scores[i-1]:.2f}', ha='center', va='top', fontsize=10, color='red')

plt.xlabel("Number of Neighbors (K)")
plt.ylabel("Score")
plt.title("KNN Accuracy & F1 Score vs. Number of Neighbors (Standardized Data)")
plt.xticks(range(1, 31))
plt.grid(True)
plt.legend()
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score ,confusion_matrix ,f1_score
from sklearn.preprocessing import StandardScaler


gnb= GaussianNB()
X_train = data.drop(['satisfaction'],axis=1)
y_train=data['satisfaction']
#y_train=
#scaler=StandardScaler()
#X_train=scaler.fit_transform(X_train)


gnb.fit(X_train,y_train)


X_test = data_test.drop(['satisfaction'],axis=1)
#X_test = scaler.transform(X_test)
y_test = data_test['satisfaction']

y_pred=gnb.predict(X_test)


print(accuracy_score(y_true=y_test,y_pred=y_pred))
print(confusion_matrix(y_true=y_test,y_pred=y_pred))
print(f1_score(y_true=y_test,y_pred=y_pred))
# Out:
# 0.8619879889128427
# [[13080  1493]
#  [ 2092  9311]]
# 0.8385644166253884

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score ,confusion_matrix ,f1_score
from sklearn.preprocessing import StandardScaler


gnb= GaussianNB()
X_train = data.drop(['satisfaction'],axis=1)
y_train=data['satisfaction']
#y_train=
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)


gnb.fit(X_train,y_train)


X_test = data_test.drop(['satisfaction'],axis=1)
X_test = scaler.transform(X_test)
y_test = data_test['satisfaction']

y_pred=gnb.predict(X_test)


print(accuracy_score(y_true=y_test,y_pred=y_pred))
print(confusion_matrix(y_true=y_test,y_pred=y_pred))
print(f1_score(y_true=y_test,y_pred=y_pred))
# Out:
# 0.8626039421004004
# [[13098  1475]
#  [ 2094  9309]]
# 0.8391400369585793

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score ,recall_score 
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree


X_train = data.drop(['satisfaction'], axis=1)
y_train = data['satisfaction']
X_test = data_test.drop(['satisfaction'], axis=1)
y_test = data_test['satisfaction']


# RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

print("RandomForestClassifier Results:")
print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))
print("F1 Score:", f1_score(y_test, y_pred_rf))

# LogisticRegression
lr = LogisticRegression(max_iter=1000, random_state=42)
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)

print("\nLogisticRegression Results:")
print("Accuracy:", accuracy_score(y_test, y_pred_lr))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_lr))
print("F1 Score:", f1_score(y_test, y_pred_lr))

# DecisionTreeClassifier

dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)

print("\nDecisionTreeClassifier Results:")
print("Accuracy:", accuracy_score(y_test, y_pred_dt))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_dt))
print("F1 Score:", f1_score(y_test, y_pred_dt))
print("Recall Score:", recall_score(y_test, y_pred_dt))

# Plot the decision tree
plt.figure(figsize=(20, 10))
plot_tree(dt, filled=True, feature_names=data.columns[:-1], class_names=['Neutral or dissatisfied', 'Satisfied'], rounded=True)
plt.show()
# Out:
# RandomForestClassifier Results:
# Accuracy: 0.9630428087465353
# Confusion Matrix:
#  [[14276   297]
#  [  663 10740]]
# F1 Score: 0.9572192513368984
# /home/tiago/Documents/UC/AC/teste/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression Results:
# Accuracy: 0.8666846319679704
# Confusion Matrix:
#  [[12997  1576]
#  [ 1887  9516]]
# F1 Score: 0.846054678817515
#
# DecisionTreeClassifier Results:
# Accuracy: 0.9464120726824762
# Confusion Matrix:
#  [[13858   715]
#  [  677 10726]]
# F1 Score: 0.9390649623533531
# Recall Score: 0.940629658861703

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.preprocessing import StandardScaler

X_train = data.drop(['satisfaction'], axis=1)
y_train = data['satisfaction']
X_test = data_test.drop(['satisfaction'], axis=1)
y_test = data_test['satisfaction']

# Scale the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
rf.feature_importances_


print("RandomForestClassifier Results:")
print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))
print("F1 Score:", f1_score(y_test, y_pred_rf))

# LogisticRegression
lr = LogisticRegression(max_iter=1000, random_state=42)
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)

print("\nLogisticRegression Results:")
print("Accuracy:", accuracy_score(y_test, y_pred_lr))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_lr))
print("F1 Score:", f1_score(y_test, y_pred_lr))

# DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)

print("\nDecisionTreeClassifier Results:")
print("Accuracy:", accuracy_score(y_test, y_pred_dt))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_dt))
print("F1 Score:", f1_score(y_test, y_pred_dt))
print("Feature Importances:", dt.feature_importances_)
print("dt score",dt.score(X_train,y_train))
print("Recall Score:", recall_score(y_test, y_pred_dt))

# Plot the decision tree
plt.figure(figsize=(20, 10))
plot_tree(dt, filled=True, feature_names=data.columns[:-1], class_names=['Neutral or dissatisfied', 'Satisfied'], rounded=True)
plt.show()
# Out:
# RandomForestClassifier Results:
# Accuracy: 0.9630428087465353
# Confusion Matrix:
#  [[14279   294]
#  [  666 10737]]
# F1 Score: 0.9572078095747526
#
# LogisticRegression Results:
# Accuracy: 0.871034801355097
# Confusion Matrix:
#  [[13126  1447]
#  [ 1903  9500]]
# F1 Score: 0.8501118568232662
#
# DecisionTreeClassifier Results:
# Accuracy: 0.9464505697566985
# Confusion Matrix:
#  [[13857   716]
#  [  675 10728]]
# F1 Score: 0.9391167330502911
# Feature Importances: [0.0023534  0.04043514 0.02377262 0.14664274 0.02174624 0.02539779
#  0.17843074 0.00635574 0.00321415 0.02229166 0.00426437 0.36212917
#  0.01640091 0.04758119 0.00881807 0.01166164 0.01493905 0.02724594
#  0.01637687 0.00890729 0.01103528]
# dt score 1.0
# Recall Score: 0.9408050513022889
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 56
#      54 plt.figure(figsize=(20, 10))
#      55 plot_tree(dt, filled=True, feature_names=data.columns[:-1], class_names=['Neutral or dissatisfied', 'Satisfied'], rounded=True)
# ---> 56 plt.show()
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib/pyplot.py:614, in show(*args, **kwargs)
#     570 """
#     571 Display all open figures.
#     572
#    (...)
#     611 explicitly there.
#     612 """
#     613 _warn_if_gui_out_of_main_thread()
# --> 614 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/IPython/core/formatters.py:238, in DisplayFormatter.format(self, obj, include, exclude)
#     236 md = None
#     237 try:
# --> 238     data = formatter(obj)
#     239 except:
#     240     # FIXME: log the exception
#     241     raise
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/decorator.py:235, in decorate.<locals>.fun(*args, **kw)
#     233 if not kwsyntax:
#     234     args, kw = fix(args, kw, sig)
# --> 235 return caller(func, *(extras + args), **kw)
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/IPython/core/formatters.py:282, in catch_format_error(method, self, *args, **kwargs)
#     280 """show traceback on failed format call"""
#     281 try:
# --> 282     r = method(self, *args, **kwargs)
#     283 except NotImplementedError:
#     284     # don't warn on NotImplementedErrors
#     285     return self._check_return(None, args[0])
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/IPython/core/formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib/backend_bases.py:2155, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2152     # we do this instead of `self.figure.draw_without_rendering`
#    2153     # so that we can inject the orientation
#    2154     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2155         self.figure.draw(renderer)
#    2156 if bbox_inches:
#    2157     if bbox_inches == "tight":
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib/artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib/figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib/axes/_base.py:3181, in _AxesBase.draw(self, renderer)
#    3178 if artists_rasterized:
#    3179     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3181 mimage._draw_list_compositing_images(
#    3182     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3184 renderer.close_group('axes')
#    3185 self.stale = False
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib/text.py:2000, in Annotation.draw(self, renderer)
#    1997     if (self.arrow_patch.get_figure(root=False) is None and
#    1998             (fig := self.get_figure(root=False)) is not None):
#    1999         self.arrow_patch.set_figure(fig)
# -> 2000     self.arrow_patch.draw(renderer)
#    2001 # Draw text, including FancyBboxPatch, after FancyArrowPatch.
#    2002 # Otherwise, a wedge arrowstyle can land partly on top of the Bbox.
#    2003 Text.draw(self, renderer)
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib/artist.py:38, in _prevent_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      35     renderer.stop_rasterizing()
#      36     renderer._rasterizing = False
# ---> 38 return draw(artist, renderer, *args, **kwargs)
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib/patches.py:4462, in FancyArrowPatch.draw(self, renderer)
#    4458 # FIXME: dpi_cor is for the dpi-dependency of the linewidth.  There
#    4459 # could be room for improvement.  Maybe _get_path_in_displaycoord could
#    4460 # take a renderer argument, but get_path should be adapted too.
#    4461 self._dpi_cor = renderer.points_to_pixels(1.)
# -> 4462 path, fillable = self._get_path_in_displaycoord()
#    4464 if not np.iterable(fillable):
#    4465     path = [path]
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib/patches.py:4437, in FancyArrowPatch._get_path_in_displaycoord(self)
#    4435     posB = self._convert_xy_units(self._posA_posB[1])
#    4436     (posA, posB) = self.get_transform().transform((posA, posB))
# -> 4437     _path = self.get_connectionstyle()(posA, posB,
#    4438                                        patchA=self.patchA,
#    4439                                        patchB=self.patchB,
#    4440                                        shrinkA=self.shrinkA * dpi_cor,
#    4441                                        shrinkB=self.shrinkB * dpi_cor
#    4442                                        )
#    4443 else:
#    4444     _path = self.get_transform().transform_path(self._path_original)
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib/patches.py:2837, in ConnectionStyle._Base.__call__(self, posA, posB, shrinkA, shrinkB, patchA, patchB)
#    2831 path = self.connect(posA, posB)
#    2832 path = self._clip(
#    2833     path,
#    2834     self._in_patch(patchA) if patchA else None,
#    2835     self._in_patch(patchB) if patchB else None,
#    2836 )
# -> 2837 path = self._clip(
#    2838     path,
#    2839     inside_circle(*path.vertices[0], shrinkA) if shrinkA else None,
#    2840     inside_circle(*path.vertices[-1], shrinkB) if shrinkB else None
#    2841 )
#    2842 return path
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib/patches.py:2815, in ConnectionStyle._Base._clip(self, path, in_start, in_stop)
#    2813 if in_start:
#    2814     try:
# -> 2815         _, path = split_path_inout(path, in_start)
#    2816     except ValueError:
#    2817         pass
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib/bezier.py:378, in split_path_inout(path, inside, tolerance, reorder_inout)
#     375     raise ValueError("The path does not intersect with the patch")
#     377 bp = bezier_path.reshape((-1, 2))
# --> 378 left, right = split_bezier_intersecting_with_closedpath(
#     379     bp, inside, tolerance)
#     380 if len(left) == 2:
#     381     codes_left = [Path.LINETO]
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib/bezier.py:344, in split_bezier_intersecting_with_closedpath(bezier, inside_closedpath, tolerance)
#     339 bezier_point_at_t = bz.point_at_t
#     341 t0, t1 = find_bezier_t_intersecting_with_closedpath(
#     342     bezier_point_at_t, inside_closedpath, tolerance=tolerance)
# --> 344 _left, _right = split_de_casteljau(bezier, (t0 + t1) / 2.)
#     345 return _left, _right
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib/bezier.py:103, in split_de_casteljau(beta, t)
#     101 beta_list = [beta]
#     102 while True:
# --> 103     beta = _de_casteljau1(beta, t)
#     104     beta_list.append(beta)
#     105     if len(beta) == 1:
#
# File ~/Documents/UC/AC/teste/lib/python3.13/site-packages/matplotlib/bezier.py:90, in _de_casteljau1(beta, t)
#      81     return x1, y1, x2, y2
#      84 # BEZIER routines
#      85
#      86 # subdividing bezier curve
#      87 # http://www.cs.mtu.edu/~shene/COURSES/cs3621/NOTES/spline/Bezier/bezier-sub.html
# ---> 90 def _de_casteljau1(beta, t):
#      91     next_beta = beta[:-1] * (1 - t) + beta[1:] * t
#      92     return next_beta
#
# KeyboardInterrupt:

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score,precision_score,precision_recall_curve
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.preprocessing import StandardScaler

X_train = data.drop(['satisfaction'], axis=1)
y_train = data['satisfaction']
X_test = data_test.drop(['satisfaction'], axis=1)
y_test = data_test['satisfaction']

# Scale the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
rf.feature_importances_



print("RandomForestClassifier Results:")
print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))
print("F1 Score:", f1_score(y_test, y_pred_rf))
print("precision Score:", precision_score(y_test, y_pred_rf))
print("precision_recall_curve:", precision_recall_curve(y_test, y_pred_rf))
print("recall Score:", recall_score(y_test, y_pred_rf))

# LogisticRegression
lr = LogisticRegression(max_iter=1000, random_state=42)
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)
 

print("\nLogisticRegression Results:")
print("Accuracy:", accuracy_score(y_test, y_pred_lr))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_lr))
print("F1 Score:", f1_score(y_test, y_pred_lr))

# DecisionTreeClassifier pruned tree
dt = DecisionTreeClassifier(random_state=42,max_depth=10)
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)

print("\nDecisionTreeClassifier Results:")
print("Accuracy:", accuracy_score(y_test, y_pred_dt))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_dt))
print("F1 Score:", f1_score(y_test, y_pred_dt))
print("Feature Importances:", dt.feature_importances_)
print("dt score",dt.score(X_train,y_train))
print("Recall Score:", recall_score(y_test, y_pred_dt))

# Plot the decision tree
plt.figure(figsize=(20, 10))
plot_tree(dt, filled=True, feature_names=data.columns[:-1], class_names=['Neutral or dissatisfied', 'Satisfied'], rounded=True)
plt.show()
# Out:
# RandomForestClassifier Results:
# Accuracy: 0.9630428087465353
# Confusion Matrix:
#  [[14279   294]
#  [  666 10737]]
# F1 Score: 0.9572078095747526
# precision Score: 0.9733478379113407
# precision_recall_curve: (array([0.43898214, 0.97334784, 1.        ]), array([1.        , 0.94159432, 0.        ]), array([0, 1]))
# recall Score: 0.941594317284925
#
# LogisticRegression Results:
# Accuracy: 0.871034801355097
# Confusion Matrix:
#  [[13126  1447]
#  [ 1903  9500]]
# F1 Score: 0.8501118568232662
#
# DecisionTreeClassifier Results:
# Accuracy: 0.9459886048660302
# Confusion Matrix:
#  [[13967   606]
#  [  797 10606]]
# F1 Score: 0.9379615299579925
# Feature Importances: [0.00000000e+00 3.99950623e-02 5.61480397e-03 1.69054658e-01
#  2.19330229e-02 1.84592583e-03 2.03903648e-01 3.40370183e-04
#  9.43760118e-04 1.60431351e-02 1.62233709e-04 4.23688799e-01
#  8.05540308e-03 5.28467729e-02 1.62178814e-03 5.26441729e-03
#  8.16069363e-03 2.66768634e-02 6.67442249e-03 5.84364968e-03
#  1.33057104e-03]
# dt score 0.9493667231290422
# Recall Score: 0.9301061124265544

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score
from sklearn.preprocessing import StandardScaler

svc = SVC()
X_train = data.drop(['satisfaction'], axis=1)
y_train = data['satisfaction']

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

svc.fit(X_train, y_train)

X_test = data_test.drop(['satisfaction'], axis=1)
X_test = scaler.transform(X_test)
y_test = data_test['satisfaction']

y_pred = svc.predict(X_test)

print(accuracy_score(y_true=y_test, y_pred=y_pred))
print(confusion_matrix(y_true=y_test, y_pred=y_pred))
print(f1_score(y_true=y_test, y_pred=y_pred))
# Out:
# 0.955728364644287
# [[14128   445]
#  [  705 10698]]
# 0.9489931695200923
